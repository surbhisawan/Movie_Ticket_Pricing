# %% [markdown]
# # **Title of Project**

# %% [markdown]
# # Movie Ticket Pricing

# %% [markdown]
# ## **Objective**

# %% [markdown]
# # To Predict the Price of the Ticket

# %% [markdown]
# ## **Data Source**

# %% [markdown]
# # Kaggle

# %% [markdown]
# ## **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ## **Import Data**

# %%
#importing the dataset in the form of CSV file
df = pd.read_csv(r'https://raw.githubusercontent.com/surbhisawan/Movie_Ticket_Pricing/main/cinemaTicket_Ref.csv')

# %% [markdown]
# ## **Describe Data**

# %%
# give the first few row of the dataset
df.head(10)
# Out:
#    film_code  cinema_code  total_sales  ...  month  quarter  day
# 0       1492          304      3900000  ...      5        2    5
# 1       1492          352      3360000  ...      5        2    5
# 2       1492          489      2560000  ...      5        2    5
# 3       1492          429      1200000  ...      5        2    5
# 4       1492          524      1200000  ...      5        2    5
# 5       1492           71      1050000  ...      5        2    5
# 6       1492          163      1020000  ...      5        2    5
# 7       1492          450       750000  ...      5        2    5
# 8       1492           51       750000  ...      5        2    5
# 9       1492          522       600000  ...      5        2    5
#
# [10 rows x 14 columns]

# %%
# give the last few line of the dataset
df.tail()
# Out:
#         film_code  cinema_code  total_sales  ...  month  quarter  day
# 142519       1569          495      1320000  ...     11        4    4
# 142520       1569          474      1200000  ...     11        4    4
# 142521       1569          524      1060000  ...     11        4    4
# 142522       1569          529       600000  ...     11        4    4
# 142523       1569          486       250000  ...     11        4    4
#
# [5 rows x 14 columns]

# %%
#give the all columns present in the dataset
df.columns
# Out:
# Index(['film_code', 'cinema_code', 'total_sales', 'tickets_sold',
#        'tickets_out', 'show_time', 'occu_perc', 'ticket_price', 'ticket_use',
#        'capacity', 'date', 'month', 'quarter', 'day'],
#       dtype='object')

# %%
#give the information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142524 entries, 0 to 142523
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   film_code     142524 non-null  int64
#  1   cinema_code   142524 non-null  int64
#  2   total_sales   142524 non-null  int64
#  3   tickets_sold  142524 non-null  int64
#  4   tickets_out   142524 non-null  int64
#  5   show_time     142524 non-null  int64
#  6   occu_perc     142399 non-null  float64
#  7   ticket_price  142524 non-null  float64
#  8   ticket_use    142524 non-null  int64
#  9   capacity      142399 non-null  float64
#  10  date          142524 non-null  object
#  11  month         142524 non-null  int64
#  12  quarter       142524 non-null  int64
#  13  day           142524 non-null  int64
# dtypes: float64(3), int64(10), object(1)
# memory usage: 15.2+ MB

# %%
#give the summary of the dataset
df.describe()
# Out:
#            film_code    cinema_code  ...        quarter            day
# count  142524.000000  142524.000000  ...  142524.000000  142524.000000
# mean     1518.985111     320.378427  ...       2.634721      16.112585
# std        36.184450     159.701229  ...       0.809692       8.949471
# min      1471.000000      32.000000  ...       1.000000       1.000000
# 25%      1485.000000     181.000000  ...       2.000000       8.000000
# 50%      1498.000000     324.000000  ...       3.000000      16.000000
# 75%      1556.000000     474.000000  ...       3.000000      24.000000
# max      1589.000000     637.000000  ...       4.000000      31.000000
#
# [8 rows x 13 columns]

# %%
#find the pairwise correlation of all columns in the dataframe
df.corr()
# Out:
#               film_code  cinema_code  total_sales  ...     month   quarter       day
# film_code      1.000000     0.029530     0.009802  ...  0.851380  0.800933 -0.028686
# cinema_code    0.029530     1.000000    -0.012910  ...  0.051027  0.049646 -0.000270
# total_sales    0.009802    -0.012910     1.000000  ... -0.080568 -0.051433 -0.000424
# tickets_sold  -0.005588    -0.053716     0.915176  ... -0.103477 -0.062666 -0.005037
# tickets_out   -0.000920     0.019534     0.066810  ... -0.012448 -0.007210  0.004441
# show_time      0.076670    -0.187125     0.509812  ... -0.023297 -0.020643  0.007646
# occu_perc     -0.104120     0.125542     0.414418  ... -0.145100 -0.088856 -0.011061
# ticket_price   0.104820     0.005079     0.272450  ...  0.048007  0.042031  0.001113
# ticket_use    -0.005582    -0.053957     0.915112  ... -0.103418 -0.062634 -0.005087
# capacity       0.061224    -0.353402     0.376134  ... -0.025265 -0.023940  0.006255
# ...

# %% [markdown]
# ## **Data Visualization**

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#plot the graph for the datset
df.plot()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True ,linewidths = 2,linecolor = "white")
plt.show()

# %% [markdown]
# ## **Data Preprocessing**

# %%
#finding the null values
df.isnull().sum()
# Out:
# film_code         0
# cinema_code       0
# total_sales       0
# tickets_sold      0
# tickets_out       0
# show_time         0
# occu_perc       125
# ticket_price      0
# ticket_use        0
# capacity        125
# date              0
# month             0
# quarter           0
# day               0
# dtype: int64

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.fillna(999, inplace=True)

# %%
#to remove the null values
df.dropna(how='all', axis=1)
print(df)
# Out:
#         film_code  cinema_code  total_sales  ...  month  quarter  day
# 0            1492          304      3900000  ...      5        2    5
# 1            1492          352      3360000  ...      5        2    5
# 2            1492          489      2560000  ...      5        2    5
# 3            1492          429      1200000  ...      5        2    5
# 4            1492          524      1200000  ...      5        2    5
# ...           ...          ...          ...  ...    ...      ...  ...
# 142519       1569          495      1320000  ...     11        4    4
# 142520       1569          474      1200000  ...     11        4    4
# 142521       1569          524      1060000  ...     11        4    4
# 142522       1569          529       600000  ...     11        4    4
# 142523       1569          486       250000  ...     11        4    4
#
# [142524 rows x 14 columns]

# %%
df.corr()
# Out:
#               film_code  cinema_code  total_sales  ...     month   quarter       day
# film_code      1.000000     0.029530     0.009802  ...  0.851380  0.800933 -0.028686
# cinema_code    0.029530     1.000000    -0.012910  ...  0.051027  0.049646 -0.000270
# total_sales    0.009802    -0.012910     1.000000  ... -0.080568 -0.051433 -0.000424
# tickets_sold  -0.005588    -0.053716     0.915176  ... -0.103477 -0.062666 -0.005037
# tickets_out   -0.000920     0.019534     0.066810  ... -0.012448 -0.007210  0.004441
# show_time      0.076670    -0.187125     0.509812  ... -0.023297 -0.020643  0.007646
# occu_perc     -0.067153     0.078244     0.254471  ... -0.093695 -0.059355 -0.005723
# ticket_price   0.104820     0.005079     0.272450  ...  0.048007  0.042031  0.001113
# ticket_use    -0.005582    -0.053957     0.915112  ... -0.103418 -0.062634 -0.005087
# capacity       0.061178    -0.353127     0.375715  ... -0.025269 -0.023948  0.006258
# ...

# %%
df = df.drop(['cinema_code','occu_perc','tickets_out','capacity','month','quarter','day'], axis=1)
df.shape
# Out:
# (142524, 7)

# %%
df.corr()
# Out:
#               film_code  total_sales  ...  ticket_price  ticket_use
# film_code      1.000000     0.009802  ...      0.104820   -0.005582
# total_sales    0.009802     1.000000  ...      0.272450    0.915112
# tickets_sold  -0.005588     0.915176  ...      0.103596    0.999946
# show_time      0.076670     0.509812  ...      0.176274    0.521625
# ticket_price   0.104820     0.272450  ...      1.000000    0.103544
# ticket_use    -0.005582     0.915112  ...      0.103544    1.000000
#
# [6 rows x 6 columns]

# %%
df.head(5)
# Out:
#    film_code  total_sales  tickets_sold  ...  ticket_price  ticket_use        date
# 0       1492      3900000            26  ...      150000.0          26  2018-05-05
# 1       1492      3360000            42  ...       80000.0          42  2018-05-05
# 2       1492      2560000            32  ...       80000.0          32  2018-05-05
# 3       1492      1200000            12  ...      100000.0          12  2018-05-05
# 4       1492      1200000            15  ...       80000.0          15  2018-05-05
#
# [5 rows x 7 columns]

# %%
df['ticket_price'].astype(np.int64)
df['ticket_price'] = df['ticket_price'].fillna(0).astype(np.int64)

# %% [markdown]
# ## **Define Target Variable (y) and Feature Variables (X)**

# %%
#independent variable
X = df[['total_sales','show_time','film_code','ticket_use','tickets_sold']]

# %%
X.shape
# Out:
# (142524, 5)

# %%
#dependent variable
y = df['ticket_price']

# %%
y.shape
# Out:
# (142524,)

# %% [markdown]
# ## **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.7)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((42757, 5), (99767, 5), (42757,), (99767,))

# %% [markdown]
# ## **Modeling**

# %%
from sklearn.linear_model import LinearRegression

# %%
pip install transformers

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from transformers import pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification

# %%
X, y = make_classification(random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=252)
pipe = make_pipeline(StandardScaler(), LinearRegression())
model=pipe.fit(X_train, y_train)

pipe.score(X_test, y_test)
# Out:
# 0.806434119039481

# %% [markdown]
# # **Accuracy**

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([ 0.22926818,  0.1170592 ,  1.05307774,  0.34419569,  0.91662358,
#         0.39032849, -0.2810919 , -0.05093589,  0.9440989 ,  1.09176464,
#         0.25465091,  0.3107452 ,  1.07973528,  0.87007229,  0.08833444,
#         0.89881069,  0.97954497,  0.16107851,  0.31310038,  0.7949172 ,
#         0.9069092 ,  0.64977467, -0.14303858,  1.02874173, -0.16351298])

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test, y_pred)
# Out:
# 0.17437005146214823

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
r2_score = model.score(X_test,y_test)
print(r2_score*100,'%')
# Out:
# 80.64341190394805 %

# %%
print("Linear Regression Model Score is ",round(model.score(X_test,y_test)*100))
# Out:
# Linear Regression Model Score is  81

# %%
#graph form by the result of the Linear Regression Model

plt.subplots(figsize=(16,6))
x_points = list(range(len(y_test)))
plt.plot(x_points,y_test,label='y_true')
plt.plot(x_points,y_pred,label='y_pred')
plt.legend()
plt.show()

# %% [markdown]
# # **Explaination**

# %% [markdown]
# Firstly I imported the dataset into colab file using csv file and analyze and understood the data set properly by going through some of the info like columns, info, etc.
#
# After analyzing, I found correlation between all columns and plotted the graph to find out relation between different columns using heatmap.
#
# Then I spillted the data set into train set and test set , then I used the train set to create and train the model and test set to further test and found the accuracy at the end.
#
# I used the Linear Regression model and pileline method to fit the data set on the train set and then did the prediction on the test set.
#
# I scatter the prediction of Y as per the input X_test using matplot library and then plotted using seaborn library.
#
# At last I found the accuracy of the prediction.
